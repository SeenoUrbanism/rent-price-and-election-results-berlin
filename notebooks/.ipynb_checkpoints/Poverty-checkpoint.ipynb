# %%
import pandas as pd
import numpy as np
import yaml
import pypdf
# import requests
# from bs4 import BeautifulSoup

# %%
import os
ext = os.path.splitext(config['input_data']['economical'])[1]

engine = "xlrd" if ext == ".xls" else "openpyxl"

poverty = pd.read_excel(
    config['input_data']['economical'],
    sheet_name="Armut",
    engine=engine
)

# %%
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except FileNotFoundError:
    print("Yaml configuration file not found!")

# Read the 'armut' sheet from the Excel file defined in config.yaml
poverty = pd.read_excel(
    config['input_data']['economical'],  # path from your YAML config
    sheet_name="Armut",                  # specify the sheet
    engine="openpyxl"                    # for .xlsx files
)

print(poverty.head())
# Out:
#   A1a I Armutsgefährdungsquoten der Bevölkerung1 2005 bis 2024 nach Berliner Bezirken und \n           Brandenburger Kreisen und kreisfreien Städten  \
# 0                         Ergebnisse des Mikrozensus
# 1                                                NaN
# 2                                             Region
# 3                                                NaN
# 4                                                NaN
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        NaN       2005      2006.0      2007.0      2008.0      2009.0
# 3        NaN          %         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 12  Unnamed: 13  \
# ...

# %%
poverty
# Out:
#    A1a I Armutsgefährdungsquoten der Bevölkerung1 2005 bis 2024 nach Berliner Bezirken und \n           Brandenburger Kreisen und kreisfreien Städten  \
# 0                          Ergebnisse des Mikrozensus
# 1                                                 NaN
# 2                                              Region
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                              Berlin
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# ...

# %%
#chart > div > div.map-outer > svg > g > path
